# %% [markdown]
# #### Nome: João Marcos Alves Modesto Ramos
# #### Mattricula : 3506

# %%
import pandas as pd

# %% [markdown]
# ## Lendo o CSV

# %%
dfCsv = pd.read_csv('dados/titanic_train.csv')
dfCsv
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Lendo JSON

# %%
dfIris = pd.read_json("dados/iris.json")
dfIris
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
import json




with open('dados/champion_info.json','r') as f:
    data = json.loads(f.read())

pd.json_normalize(data['data'],max_level=1)


dfChamp = pd.read_json("dados/champion_info.json")
dfChamp = pd.json_normalize(dfChamp['data'])
dfChamp
# Out:
#                       title   id      key     name
# 0            the Dark Child    1    Annie    Annie
# 1             The Judicator   10    Kayle    Kayle
# 2       the Magus Ascendant  101   Xerath   Xerath
# 3           the Half-Dragon  102  Shyvana  Shyvana
# 4       the Nine-Tailed Fox  103     Ahri     Ahri
# ..                      ...  ...      ...      ...
# 133      the Blade's Shadow   91    Talon    Talon
# 134               the Exile   92    Riven    Riven
# 135  the Mouth of the Abyss   96   KogMaw  Kog'Maw
# 136     the Eye of Twilight   98     Shen     Shen
# 137  the Lady of Luminosity   99      Lux      Lux
#
# [138 rows x 4 columns]

# %%
dfChamp.hea
# Out:
#                           title   id         key        name
# 0                the Dark Child    1       Annie       Annie
# 1                 The Judicator   10       Kayle       Kayle
# 2           the Magus Ascendant  101      Xerath      Xerath
# 3               the Half-Dragon  102     Shyvana     Shyvana
# 4           the Nine-Tailed Fox  103        Ahri        Ahri
# ..                          ...  ...         ...         ...
# 95         the Master Tactician   50       Swain       Swain
# 96      the Sheriff of Piltover   51     Caitlyn     Caitlyn
# 97  The Fire below the Mountain  516        Ornn        Ornn
# 98        the Great Steam Golem   53  Blitzcrank  Blitzcrank
# 99        Shard of the Monolith   54    Malphite    Malphite
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Lendo XLS

# %%
dfPib = pd.read_excel('dados/PIB dos Municipios - base de dados 2010-2016.xls')
dfPib
# Out:
#         Ano  Código da Grande Região Nome da Grande Região  \
# 0      2010                        1                 Norte
# 1      2010                        1                 Norte
# 2      2010                        1                 Norte
# 3      2010                        1                 Norte
# 4      2010                        1                 Norte
# ...     ...                      ...                   ...
# 24932  2014                        3               Sudeste
# 24933  2014                        3               Sudeste
# 24934  2014                        3               Sudeste
# 24935  2014                        3               Sudeste
# 24936  2014                        3               Sudeste
#
#        Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                                  11                            RO
# 1                                  11                            RO
# ...

# %% [markdown]
# ## Lendo parquet

# %%
dfTrack = pd.read_parquet('dados/user_tracking.parquet')
dfTrack
# Out:
#       installation_number external_identifier                   handset  \
# 0                 7206043                              samsung:SM-J700M
# 1                 6219664           367738313      LENOVO:Lenovo K33b36
# 2                 6485586                              samsung:SM-G928G
# 3                 7050958           108659666          samsung:SM-G930F
# 4                 7131516           108027625           asus:ASUS_X013D
# ...                   ...                 ...                       ...
# 28291             7210849                      motorola:Moto G (5) Plus
# 28292             6660693           441385055     motorola:Moto Z2 Play
# 28293             6848495           506809026          samsung:SM-J700M
# 28294             7110078                          motorola:Moto G (5S)
# 28295             6272408           475939424          samsung:SM-G610F
#
#             os os_version         host_app_package host_app_version  \
# ...

# %% [markdown]
# ## Lendo SQL

# %%
import sqlite3 as sql

# %%
## Criando o database
databaseName = 'clienteCidade.db'
connection = sql.connect(databaseName)

sql_file = open("dados/cliente_cidade.sql", encoding='UTF-8')
sql_as_string = sql_file.read()
connection.executescript(sql_as_string)

# %%
querry = '''SELECT * FROM Cliente'''
dfSQL = pd.read_sql_query(querry,connection)
dfSQL
# Out:
#      idCliente                                         nome  codIBGE
# 0            7              Prefeitura Municipal de Aimorés  3101102
# 1           16             Prefeitura Municipal de Argirita  3104403
# 2           20             Prefeitura Municipal de Bandeira  3105202
# 3           21      Prefeitura Municipal de Barão de Cocais  3105400
# 4           22  Prefeitura Municipal de Bela Vista de Minas  3106002
# ..         ...                                          ...      ...
# 162        431                Prefeitura Municipal de Palma  3146701
# 163        432         Prefeitura de Santa Maria de Itabira  3158003
# 164        435                Câmara Municipal de Tarumirim     None
# 165        436       Câmara Municipal de Fernandes Tourinho     None
# 166        437              Câmara Municipal de Sabinópolis     None
#
# [167 rows x 3 columns]

# %% [markdown]
# ## Recebendo da API

# %%
import requests

# %%
json = requests.get("https://servicodados.ibge.gov.br/api/v1/localidades/estados/31/municipios").json()
dadosMunicipio = pd.DataFrame.from_dict(json)
dadosMunicipio
# Out:
#           id                    nome  \
# 0    3100104     Abadia dos Dourados
# 1    3100203                  Abaeté
# 2    3100302              Abre Campo
# 3    3100401                 Acaiaca
# 4    3100500                 Açucena
# ..       ...                     ...
# 848  3171808            Virginópolis
# 849  3171907             Virgolândia
# 850  3172004  Visconde do Rio Branco
# 851  3172103            Volta Grande
# 852  3172202          Wenceslau Braz
#
#                                           microrregiao  \
# 0    {'id': 31019, 'nome': 'Patrocínio', 'mesorregi...
# 1    {'id': 31024, 'nome': 'Três Marias', 'mesorreg...
# 2    {'id': 31061, 'nome': 'Manhuaçu', 'mesorregiao...
# 3    {'id': 31060, 'nome': 'Ponte Nova', 'mesorregi...
# 4    {'id': 31039, 'nome': 'Ipatinga', 'mesorregiao...
# ..                                                 ...
# 848  {'id': 31035, 'nome': 'Guanhães', 'mesorregiao...
# 849  {'id': 31037, 'nome': 'Governador Valadares', ...
# ...
